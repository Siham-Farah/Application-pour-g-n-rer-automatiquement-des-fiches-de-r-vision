# %%
import os
import fitz  # PyMuPDF
from docx import Document
from pptx import Presentation
from pymongo import MongoClient
from datetime import datetime

# ---------------------------
# 1. Configuration initiale
# ---------------------------

# Dossier contenant les fichiers 
BASE_DIR = r"C:\Users\Romaissae\OneDrive\Desktop\Javascript"
FORMATS = ["pdf", "docx", "pptx"]  # Formats acceptés

# Connexion MongoDB
try:
    client = MongoClient("mongodb://localhost:27017/")
    db = client["projet_Sd"]
    collection = db["programmation_js"]
    client.admin.command('ping')  # Vérifier la connexion
    print("✅ Connexion MongoDB réussie")
except Exception as e:
    print(f"❌ Erreur de connexion MongoDB : {str(e)}")
    exit()

# ---------------------------
# 2. Fonctions d'extraction
# ---------------------------

def extract_pdf_text(file_path):
    """Extrait le texte d'un PDF avec PyMuPDF"""
    try:
        doc = fitz.open(file_path)
        return " ".join([page.get_text() for page in doc])
    except Exception as e:
        print(f"❌ Erreur extraction PDF {file_path} : {str(e)}")
        return ""

def extract_docx_text(file_path):
    """Extrait le texte d'un DOCX avec python-docx"""
    try:
        doc = Document(file_path)
        return "\n".join([para.text for para in doc.paragraphs])
    except Exception as e:
        print(f"❌ Erreur extraction DOCX {file_path} : {str(e)}")
        return ""

def extract_pptx_text(file_path):
    """Extrait le texte d'un PPTX avec python-pptx"""
    try:
        prs = Presentation(file_path)
        text = []
        for slide in prs.slides:
            for shape in slide.shapes:
                if hasattr(shape, "text"):
                    text.append(shape.text)
        return "\n".join(text)
    except Exception as e:
        print(f"❌ Erreur extraction PPTX {file_path} : {str(e)}")
        return ""

# ---------------------------
# 3. Parcours des fichiers
# ---------------------------

inserted_count = 0  # Compteur des fichiers insérés

for filename in os.listdir(BASE_DIR):  # Liste tous les fichiers du dossier
    file_path = os.path.join(BASE_DIR, filename)
    
    # Vérifie si c'est un fichier et s'il a une extension supportée
    if not os.path.isfile(file_path) or not filename.lower().endswith(tuple(FORMATS)):
        continue  # Ignore les fichiers non valides

    print(f"✅ Fichier trouvé : {filename}")  # Vérification

    # Extraction du texte selon le format
    try:
        if filename.endswith(".pdf"):
            content = extract_pdf_text(file_path)
        elif filename.endswith(".docx"):
            content = extract_docx_text(file_path)
        elif filename.endswith(".pptx"):
            content = extract_pptx_text(file_path)

        if not content.strip():
            print(f"⚠ Fichier vide ou erreur d'extraction : {filename}")
            continue
        else:
            print(f"✅ Extraction réussie pour : {filename}")
    except Exception as e:
        print(f"❌ Erreur avec {filename}: {str(e)}")
        continue

    # Structure des données à insérer
    document = {
        "title": filename,
        "content": content,
        "file_type": filename.split('.')[-1],
        "source": "Université XYZ",
        "extracted_date": datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }

    # Insertion dans MongoDB
    collection.insert_one(document)
    inserted_count += 1  # Incrémentation du compteur

print(f"📌 {inserted_count} cours insérés dans MongoDB !")

# ---------------------------
# 4. Vérification
# ---------------------------

if inserted_count > 0:
    print("\n📌 Affichage de 3 documents insérés :")
    for doc in collection.find().limit(3):
        print(f"\n--- {doc['title']} ---")
        print(doc["content"][:200] + "...")  # Affiche les 200 premiers caractères
else:
    print("⚠ Aucun document inséré, vérifie les logs ci-dessus.")
# Out:
# ✅ Connexion MongoDB réussie
# ✅ Fichier trouvé : 0618-javascript-es6-de-a-a-z.pdf
# ✅ Extraction réussie pour : 0618-javascript-es6-de-a-a-z.pdf
# ✅ Fichier trouvé : 9782409016219.pdf
# ✅ Extraction réussie pour : 9782409016219.pdf
# ✅ Fichier trouvé : AWA_04_IntroVueJS.pdf
# ✅ Extraction réussie pour : AWA_04_IntroVueJS.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_Chap 1_241105_160541.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_Chap 1_241105_160541.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_Chap 2.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_Chap 2.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_Chap 3-2IAD.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_Chap 3-2IAD.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_Chap 4-2IAD.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_Chap 4-2IAD.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_P2-Chap 1-2IAD.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_P2-Chap 1-2IAD.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_P2-Chap 2-2IAD.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_P2-Chap 2-2IAD.pdf
# ✅ Fichier trouvé : Dev-Multiplateforme_P2-Chap 3-2IAD.pdf
# ✅ Extraction réussie pour : Dev-Multiplateforme_P2-Chap 3-2IAD.pdf
# ✅ Fichier trouvé : JavaScript_L_Essentiel_du_code_et_des_commandes_par_La_grande_bibliotheque_numerique.pdf
# ✅ Extraction réussie pour : JavaScript_L_Essentiel_du_code_et_des_commandes_par_La_grande_bibliotheque_numerique.pdf
# ✅ Fichier trouvé : js-1-26.pdf
# ⚠ Fichier vide ou erreur d'extraction : js-1-26.pdf
# ✅ Fichier trouvé : js-111-147.pdf
# ⚠ Fichier vide ou erreur d'extraction : js-111-147.pdf
# ✅ Fichier trouvé : js-148-458.pdf
# ⚠ Fichier vide ou erreur d'extraction : js-148-458.pdf
# ✅ Fichier trouvé : js-26-50.pdf
# ⚠ Fichier vide ou erreur d'extraction : js-26-50.pdf
# ✅ Fichier trouvé : js-50-90.pdf
# ⚠ Fichier vide ou erreur d'extraction : js-50-90.pdf
# ✅ Fichier trouvé : js-90-111.pdf
# ⚠ Fichier vide ou erreur d'extraction : js-90-111.pdf
# ✅ Fichier trouvé : js.pdf
# ⚠ Fichier vide ou erreur d'extraction : js.pdf
# ✅ Fichier trouvé : Mon Cours JS (2).pdf
# ✅ Extraction réussie pour : Mon Cours JS (2).pdf
# ✅ Fichier trouvé : node-express.pdf
# ✅ Extraction réussie pour : node-express.pdf
# ✅ Fichier trouvé : nodeJs (1).pdf
# ✅ Extraction réussie pour : nodeJs (1).pdf
# ✅ Fichier trouvé : nodejs.pdf
# ✅ Extraction réussie pour : nodejs.pdf
# ✅ Fichier trouvé : react.892.pdf
# ✅ Extraction réussie pour : react.892.pdf
# ✅ Fichier trouvé : redecouvrir-javascript-avec-nodejs.pdf
# ✅ Extraction réussie pour : redecouvrir-javascript-avec-nodejs.pdf
# ✅ Fichier trouvé : sem1-intro.pdf
# ✅ Extraction réussie pour : sem1-intro.pdf
# ✅ Fichier trouvé : slidesJavascriptFr.pdf
# ✅ Extraction réussie pour : slidesJavascriptFr.pdf
# ✅ Fichier trouvé : tp3_express.pdf
# ✅ Extraction réussie pour : tp3_express.pdf
# ✅ Fichier trouvé : Whitepaper-NodeJS-FR.pdf
# ✅ Extraction réussie pour : Whitepaper-NodeJS-FR.pdf
# 📌 21 cours insérés dans MongoDB !
#
# 📌 Affichage de 3 documents insérés :
#
# --- 0618-javascript-es6-de-a-a-z.pdf ---
#  0
# 1
# 1.1
# 1.2
# 2
# 3
# 4
# 4.1
# 5
# 5.1
# 5.2
# 5.3
# 6
# 7
# 8
# 9
# 9.1
# 9.2
# 9.3
# 10
# 10.1
# 11
# 11.1
# 11.2
# 12
# 13
# 14
# 14.1
# 14.2
# 14.3
# Table des matières
# Introduction
# La déclaration de variable
# `let`
# `const`
# Les objets littéraux
# `Sym...
#
# --- 9782409016219.pdf ---
# JavaScript
# et jQuery
# La programmation web
# par la pratique
#
# Frédéric DELOBEL
#  1
# Table des matières
# Avant-propos
# Partie 1 : JavaScript
# Chapitre 1-1
# Présentation de JavaScript
# 1.
# Qu'est-ce que JavaScrip...
#
# --- AWA_04_IntroVueJS.pdf ---
# Introduction à Vue.js (v3)
# Philippe Genoud
# Philippe.Genoud@univ-grenoble-alpes.fr
# Dernière mise à jour : 07/02/2024 12:41
#  Qu'est-ce que Vue.js ?
# • Vue.js : un framework JavaScript open-source et prog...
